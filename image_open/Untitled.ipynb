# %%
# Pillow kutuphane kullanarak
from PIL import Image
img=Image.open("/home/demet/Belgeler/foto-kirpma/demet.png")
img.show()

# %%
#opencv kullanarak
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/home/demet/Belgeler/foto-kirpma/demet.png')

plt.imshow(img)
plt.show()

# %%
# renkler düzeltmek için
# BGR -> RGB // MYK -> KYM
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-fbdcdb9589e8> in <module>()
#       1 # renkler düzeltmek için
#       2 # BGR -> RGB // MYK -> KYM
# ----> 3 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(img)
#       5 plt.show()
#
# TypeError: src is not a numpy array, neither a scalar
